# %%
# %load_ext autoreload

# %%
# %autoreload

import numpy as np

from environment import DecisionEnvironment, DecisionEnvironmentGrid
from decision_maker import DecisionMaker, DecisionMakerGrid

# %%
DecisionEnvironment(N=2000).plot_gain()

# %%
DecisionEnvironment(N=2000, V=0.0).plot_gain()

# %%
DecisionEnvironment(N=2000, V=0.1).plot_gain()

# %%
DecisionEnvironment(N=2000, V=2).plot_gain()

# %%
DecisionEnvironment(N=2000, V=10).plot_gain()

# %%
DecisionEnvironment(N=2000, sigma=0.1).plot_gain()

# %%
DecisionEnvironment(N=2000, sigma=0.5).plot_gain()

# %%
DecisionEnvironment(N=2000, sigma=2).plot_gain()

# %%
DecisionEnvironment(N=2000, sigma=20).plot_gain()

# %%
deg = DecisionEnvironmentGrid({"sigma": np.linspace(0.1, 10, num=25), "V": [0.1, 1, 5]})
deg.plot_complex("Average Utility as a function of sigma for V'=0", mode="gain", N=1000)

# %%
deg = DecisionEnvironmentGrid({"V": np.linspace(0.1, 10, num=50),"sigma": [0.2, 1, 2]})
deg.plot_complex("Average Utility as a function of V", mode="gain", N=1000)

# %%
dm = DecisionMaker(cost_eval=0.1)
deg = DecisionEnvironmentGrid({"sigma": np.linspace(0.1, 4, num=25),
                               "V": [1, 2, 5]})
deg.plot_complex(
    "Average Utility (and Probability in red) as a function of V for Evaluation Cost 0.1", 
    dm=dm, 
    N=1000)

# %%
dm = DecisionMaker(cost_eval=0.5)
deg = DecisionEnvironmentGrid({"sigma": np.linspace(0.1, 8, num=25),
                               "V": [1, 2, 5]})
deg.plot_complex(
    "Average Utility (and Probability in red) as a function of V for Evaluation Cost 0.5",
    dm=dm, 
    N=1000)

# %%
dmg = DecisionMakerGrid({"threshold": np.linspace(0, 0.6, num=25), "cost_eval": [0, 0.1, 0.2, 0.3]})
env = DecisionEnvironment(N=10000)
dmg.plot_complex("Average Utility as a function of Threshold", env=env)

# %%
dmg = DecisionMakerGrid({"cost_eval": np.linspace(0, 0.5, num=25), "threshold": [0, 0.1, 0.2, 0.3]})
env = DecisionEnvironment(N=10000)
dmg.plot_complex("Average Utility as a function of Evaluation Cost", env=env)
